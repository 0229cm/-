# %% [markdown]
# # Transformer (Translation)

# %%
import random
import numpy as np
import tensorflow as tf
from konlpy.tag import Okt

from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Lambda, Layer, Embedding, LayerNormalization

# %%
# %pwd
# Out:
# 'C:\\Users\\min\\딥러닝 과제'

# %%
import os
os.chdir('C:\\Users\\min\\Desktop\\study\\lv2 deep learning')

# %%
# %pwd
# Out:
# 'C:\\Users\\min\\Desktop\\study\\lv2 deep learning'

# %%
EPOCHS = 200
NUM_WORDS = 2000

# %% [markdown]
# ## Dot-Scaled Attention

# %%
class DotScaledAttention(Layer):
    def __init__(self, d_emb, d_reduced, masked=False):
        super().__init__()
        self.q = Dense(d_reduced, input_shape=(-1, d_emb))
        self.k = Dense(d_reduced, input_shape=(-1, d_emb))
        self.v = Dense(d_reduced, input_shape=(-1, d_emb))
        self.scale = Lambda(lambda x: x/np.sqrt(d_reduced))
        self.masked = masked

    def call(self, x, training=None, mask=None): # (q,k,v)
        q = self.scale(self.q(x[0]))
        k = self.k(x[1])
        v = self.v(x[2])
        
        k_T = tf.transpose(k, perm=[0, 2, 1])
        comp = tf.matmul(q, k_T)
        

        if self.masked: # Referred from https://github.com/LastRemote/Transformer-TF2.0
            length = tf.shape(comp)[-1]
            mask = tf.fill((length, length), -np.inf)
            mask = tf.linalg.band_part(mask, 0, -1) # Get upper triangle
            mask = tf.linalg.set_diag(mask, tf.zeros((length))) # Set diagonal to zeros to avoid operations with infinity
            comp += mask
        comp = tf.nn.softmax(comp, axis=-1)
        return tf.matmul(comp, v)

# %% [markdown]
# ## Multi-Head Attention

# %%
class MultiHeadAttention(Layer):
    def __init__(self, num_head, d_emb, d_reduced, masked=False):
        super().__init__()
        self.attention_list = list()
        for _ in range(num_head):
            self.attention_list.append(DotScaledAttention(d_emb, d_reduced, masked))
        self.linear = Dense(d_emb, input_shape=(-1, num_head * d_reduced))        

    def call(self, x, training=None, mask=None):
        attention_list = [a(x) for a in self.attention_list]
        concat = tf.concat(attention_list, axis=-1)
        return self.linear(concat)

# %% [markdown]
# ## Encoder

# %%
class Encoder(Layer):
    def __init__(self, num_head, d_reduced):
        super().__init__()
        self.num_head = num_head
        self.d_r = d_reduced
    
    def build(self, input_shape):
        self.multi_attention = MultiHeadAttention(self.num_head, input_shape[-1], self.d_r)
        self.layer_norm1 = LayerNormalization(input_shape = input_shape)
        self.dense1 = Dense(input_shape[-1] * 4, input_shape = input_shape, activation='relu')
        self.dense2 = Dense(input_shape[-1],
                            input_shape = self.dense1.compute_output_shape(input_shape))
        self.layer_norm2 = LayerNormalization(input_shape=input_shape)
        super().build(input_shape)

    def call(self, x, training=None, mask=None):
        h = self.multi_attention((x, x, x))
        ln1 = self.layer_norm1(x + h)
        
        h = self.dense2(self.dense1(ln1))
        return self.layer_norm2(h + ln1)        
        
    def compute_output_shape(self, input_shape):
        return input_shape

# %% [markdown]
# ## Decoder

# %%
class Decoder(Layer):
    def __init__(self, num_head, d_reduced):
        super().__init__()
        self.num_head = num_head
        self.d_r = d_reduced
    
    def build(self, input_shape):
        self.self_attention = MultiHeadAttention(self.num_head, input_shape[0][-1], self.d_r, masked=True)
        self.layer_norm1 = LayerNormalization(input_shape = input_shape)
        
        self.multi_attention = MultiHeadAttention(self.num_head, input_shape[0][-1], self.d_r)
        self.layer_norm2 = LayerNormalization(input_shape = input_shape)
        
        self.dense1 = Dense(input_shape[0][-1] * 4, input_shape = input_shape[0], activation='relu')
        self.dense2 = Dense(input_shape[0][-1],
                            input_shape = self.dense1.compute_output_shape(input_shape[0]))
        self.layer_norm3 = LayerNormalization(input_shape=input_shape)
        super().build(input_shape)

    def call(self, inputs, training=None, mask=None): # (x, context)
        x, context = inputs
        h = self.self_attention((x, x, x))
        ln1 = self.layer_norm1(x + h)
        
        h = self.multi_attention((ln1, context, context))
        ln2 = self.layer_norm2(ln1 + h)
        
        h = self.dense2(self.dense1(ln2))
        return self.layer_norm3(h + ln2)

    def compute_output_shape(self, input_shape):
        return input_shape

# %% [markdown]
# ## Positional Encoding

# %%
class PositionalEncoding(Layer):  # Referred from https://github.com/LastRemote/Transformer-TF2.0
    def __init__(self, max_len, d_emb):
        super().__init__()
        self.sinusoidal_encoding = np.array([self.get_positional_angle(pos, d_emb) for pos in range(max_len)], dtype=np.float32)
        self.sinusoidal_encoding[:, 0::2] = np.sin(self.sinusoidal_encoding[:, 0::2])
        self.sinusoidal_encoding[:, 1::2] = np.cos(self.sinusoidal_encoding[:, 1::2])
        self.sinusoidal_encoding = tf.cast(self.sinusoidal_encoding, dtype=tf.float32)

    def call(self, x, training=None, mask=None):
        return x + self.sinusoidal_encoding[:tf.shape(x)[1]]

    def compute_output_shape(self, input_shape):
        return input_shape

    def get_angle(self, pos, dim, d_emb):
        return pos / np.power(10000, 2 * (dim // 2) / d_emb)

    def get_positional_angle(self, pos, d_emb):
        return [self.get_angle(pos, dim, d_emb) for dim in range(d_emb)]

# %% [markdown]
# ## Transformer Architecture

# %%
class Transformer(Model):
    def __init__(self, src_vocab, dst_vocab, max_len, d_emb,
                       d_reduced, n_enc_layer, n_dec_layer, num_head):
        super().__init__()
        self.enc_emb = Embedding(src_vocab, d_emb)
        self.dec_emb = Embedding(dst_vocab, d_emb)
        self.pos_enc = PositionalEncoding(max_len, d_emb)
        
        self.encoder = [Encoder(num_head, d_reduced) for _ in range(n_enc_layer)]
        self.decoder = [Decoder(num_head, d_reduced) for _ in range(n_dec_layer)]
        self.dense = Dense(dst_vocab, input_shape=(-1, d_emb))
        
    def call(self, inputs, training=None, mask=None): # (src_sentence, dst_sentence_shift)
        src_sent, dst_sent_shifted = inputs
        
        h_enc = self.pos_enc(self.enc_emb(src_sent))
        for enc in self.encoder:
            h_enc = enc(h_enc)
            
        h_dec = self.pos_enc(self.dec_emb(dst_sent_shifted))
        for dec in self.decoder:
            h_dec = dec([h_dec, h_enc])
        
        return tf.nn.softmax(self.dense(h_dec), axis=-1)

# %% [markdown]
# ## Dataset 준비

# %%
dataset_file = 'C:\\Users\\min\\Desktop\\study\\lv2 deep learning\\chatbot_data.csv' # acquired from 'http://www.aihub.or.kr' and modified
okt = Okt()

with open('C:\\Users\\min\\Desktop\\study\\lv2 deep learning\\chatbot_data.csv', 'r', encoding='UTF8') as file:
    lines = file.readlines()
    seq = [' '.join(okt.morphs(line)) for line in lines]

questions = seq[::2]
answers = ['\t ' + lines for lines in seq[1::2]]

num_sample = len(questions)

perm = list(range(num_sample))
random.seed(0)
random.shuffle(perm)

train_q = list()
train_a = list()
test_q = list()
test_a = list()

for idx, qna in enumerate(zip(questions, answers)):
    q, a = qna
    if perm[idx] > num_sample//5:
        train_q.append(q)
        train_a.append(a)
    else:
        test_q.append(q)
        test_a.append(a)

tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=NUM_WORDS,
                                                  filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~')

tokenizer.fit_on_texts(train_q + train_a)

train_q_seq = tokenizer.texts_to_sequences(train_q)
train_a_seq = tokenizer.texts_to_sequences(train_a)

test_q_seq = tokenizer.texts_to_sequences(test_q)
test_a_seq = tokenizer.texts_to_sequences(test_a)

x_train = tf.keras.preprocessing.sequence.pad_sequences(train_q_seq,
                                                        value=0,
                                                        padding='pre',
                                                        maxlen=64)
y_train = tf.keras.preprocessing.sequence.pad_sequences(train_a_seq,
                                                        value=0,
                                                        padding='post',
                                                        maxlen=65)
y_train_shifted = np.concatenate([np.zeros((y_train.shape[0], 1)), y_train[:, 1:]], axis=1)


x_test = tf.keras.preprocessing.sequence.pad_sequences(test_q_seq,
                                                       value=0,
                                                       padding='pre',
                                                       maxlen=64)
y_test = tf.keras.preprocessing.sequence.pad_sequences(test_a_seq,
                                                       value=0,
                                                       padding='post',
                                                       maxlen=65)

# %% [markdown]
# ## Train using keras

# %%
transformer = Transformer(NUM_WORDS, NUM_WORDS, 128, 16, 16, 2, 2, 4) # Instantiating a new transformer model

transformer.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
transformer.fit([x_train, y_train_shifted], y_train, batch_size=5, epochs=EPOCHS)
# Out:
# Epoch 1/200
# 80/80 [==============================] - 2s 19ms/step - loss: 6.1375 - accuracy: 0.8467
# Epoch 2/200
# 80/80 [==============================] - 1s 14ms/step - loss: 2.9152 - accuracy: 0.8900
# Epoch 3/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.0421 - accuracy: 0.8900
# Epoch 4/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.7295 - accuracy: 0.8900
# Epoch 5/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.6226 - accuracy: 0.9087
# Epoch 6/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.5602 - accuracy: 0.9200
# Epoch 7/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.5087 - accuracy: 0.9207
# Epoch 8/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.4780 - accuracy: 0.9209
# Epoch 9/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.4579 - accuracy: 0.9239
# Epoch 10/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.4370 - accuracy: 0.9263
# Epoch 11/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.4186 - accuracy: 0.9285
# Epoch 12/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.3970 - accuracy: 0.9304
# Epoch 13/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.3777 - accuracy: 0.9319
# Epoch 14/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.3584 - accuracy: 0.9345
# Epoch 15/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.3402 - accuracy: 0.9372
# Epoch 16/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.3205 - accuracy: 0.9415
# Epoch 17/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.3012 - accuracy: 0.9454
# Epoch 18/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.2842 - accuracy: 0.9486
# Epoch 19/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.2667 - accuracy: 0.9526
# Epoch 20/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2503 - accuracy: 0.9556
# Epoch 21/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.2352 - accuracy: 0.9589
# Epoch 22/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2227 - accuracy: 0.9612
# Epoch 23/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.2086 - accuracy: 0.9638
# Epoch 24/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1969 - accuracy: 0.9660
# Epoch 25/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1870 - accuracy: 0.9673
# Epoch 26/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1745 - accuracy: 0.9699
# Epoch 27/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1636 - accuracy: 0.9724
# Epoch 28/200
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1550 - accuracy: 0.9748
# Epoch 29/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1472 - accuracy: 0.9756
# Epoch 30/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1380 - accuracy: 0.9781
# Epoch 31/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1290 - accuracy: 0.9793
# Epoch 32/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1207 - accuracy: 0.9813
# Epoch 33/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1138 - accuracy: 0.9826
# Epoch 34/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1073 - accuracy: 0.9838
# Epoch 35/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1007 - accuracy: 0.9848
# Epoch 36/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0945 - accuracy: 0.9859 0s - loss: 0.0935 - accuracy
# Epoch 37/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0884 - accuracy: 0.9870
# Epoch 38/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0828 - accuracy: 0.9884
# Epoch 39/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0778 - accuracy: 0.9887
# Epoch 40/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0742 - accuracy: 0.9898 0s -
# Epoch 41/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0683 - accuracy: 0.9909
# Epoch 42/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0638 - accuracy: 0.9925
# Epoch 43/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0587 - accuracy: 0.9937
# Epoch 44/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0550 - accuracy: 0.9952
# Epoch 45/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0513 - accuracy: 0.9966
# Epoch 46/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0482 - accuracy: 0.9965
# Epoch 47/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0462 - accuracy: 0.9970
# Epoch 48/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0425 - accuracy: 0.9981
# Epoch 49/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0400 - accuracy: 0.9983
# Epoch 50/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0373 - accuracy: 0.9988
# Epoch 51/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0341 - accuracy: 0.9994
# Epoch 52/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0310 - accuracy: 0.9996
# Epoch 53/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0281 - accuracy: 0.9998
# Epoch 54/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0261 - accuracy: 0.9999
# Epoch 55/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0242 - accuracy: 0.9999
# Epoch 56/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0229 - accuracy: 0.9999
# Epoch 57/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0216 - accuracy: 0.9999 0s - loss: 0.0 - ETA: 0s - loss: 0.0209 - accuracy
# Epoch 58/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0194 - accuracy: 1.0000 0s - los
# Epoch 59/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 60/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 61/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 62/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0134 - accuracy: 1.0000 0s - loss: 0.0130 - accuracy
# Epoch 63/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 64/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 65/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 66/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 67/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 68/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 69/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 70/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 71/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 72/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 73/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 74/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 75/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 76/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 77/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 78/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 79/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 80/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 81/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 82/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 83/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 84/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 85/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 86/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 87/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 88/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 89/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 90/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 91/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 92/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 93/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 94/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 95/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 96/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 97/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 98/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 99/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 100/200
# 80/80 [==============================] - 1s 16ms/step - loss: 9.8002e-04 - accuracy: 1.0000
# Epoch 101/200
# 80/80 [==============================] - 1s 16ms/step - loss: 9.3058e-04 - accuracy: 1.0000
# Epoch 102/200
# 80/80 [==============================] - 1s 15ms/step - loss: 8.8313e-04 - accuracy: 1.0000 0s - loss: 9
# Epoch 103/200
# 80/80 [==============================] - 1s 15ms/step - loss: 8.4165e-04 - accuracy: 1.0000
# Epoch 104/200
# 80/80 [==============================] - 1s 15ms/step - loss: 7.9856e-04 - accuracy: 1.0000 0s - loss: 7.9564e-04 - accuracy: 1.00
# Epoch 105/200
# 80/80 [==============================] - 1s 15ms/step - loss: 7.5629e-04 - accuracy: 1.0000
# Epoch 106/200
# 80/80 [==============================] - 1s 15ms/step - loss: 7.2195e-04 - accuracy: 1.0000
# Epoch 107/200
# 80/80 [==============================] - 1s 15ms/step - loss: 6.8818e-04 - accuracy: 1.0000
# Epoch 108/200
# 80/80 [==============================] - 1s 15ms/step - loss: 6.6161e-04 - accuracy: 1.0000
# Epoch 109/200
# 80/80 [==============================] - 1s 16ms/step - loss: 6.3643e-04 - accuracy: 1.0000
# Epoch 110/200
# 80/80 [==============================] - 1s 15ms/step - loss: 6.0394e-04 - accuracy: 1.0000
# Epoch 111/200
# 80/80 [==============================] - 1s 15ms/step - loss: 5.6776e-04 - accuracy: 1.0000
# Epoch 112/200
# 80/80 [==============================] - 1s 15ms/step - loss: 5.3682e-04 - accuracy: 1.0000
# Epoch 113/200
# 80/80 [==============================] - 1s 16ms/step - loss: 5.0553e-04 - accuracy: 1.0000
# Epoch 114/200
# 80/80 [==============================] - 1s 15ms/step - loss: 4.7781e-04 - accuracy: 1.0000
# Epoch 115/200
# 80/80 [==============================] - 1s 15ms/step - loss: 4.6085e-04 - accuracy: 1.0000
# Epoch 116/200
# 80/80 [==============================] - 1s 15ms/step - loss: 4.3766e-04 - accuracy: 1.0000
# Epoch 117/200
# 80/80 [==============================] - 1s 15ms/step - loss: 4.1332e-04 - accuracy: 1.0000
# Epoch 118/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.9413e-04 - accuracy: 1.0000
# Epoch 119/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.7393e-04 - accuracy: 1.0000
# Epoch 120/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.5467e-04 - accuracy: 1.0000
# Epoch 121/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.3838e-04 - accuracy: 1.0000
# Epoch 122/200
# 80/80 [==============================] - 1s 16ms/step - loss: 3.2244e-04 - accuracy: 1.0000
# Epoch 123/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.0708e-04 - accuracy: 1.0000
# Epoch 124/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.9413e-04 - accuracy: 1.0000
# Epoch 125/200
# 80/80 [==============================] - 1s 16ms/step - loss: 2.8079e-04 - accuracy: 1.0000
# Epoch 126/200
# 80/80 [==============================] - 1s 16ms/step - loss: 2.6783e-04 - accuracy: 1.0000
# Epoch 127/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.5587e-04 - accuracy: 1.0000
# Epoch 128/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.4531e-04 - accuracy: 1.0000
# Epoch 129/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.3640e-04 - accuracy: 1.0000
# Epoch 130/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.2673e-04 - accuracy: 1.0000 0s - loss: 2.403
# Epoch 131/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.1516e-04 - accuracy: 1.0000 0s - loss: 2.0936e-04 - accuracy - ETA: 0s - loss: 1.9868e
# Epoch 132/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.0937e-04 - accuracy: 1.0000
# Epoch 133/200
# 80/80 [==============================] - 1s 16ms/step - loss: 2.0878e-04 - accuracy: 1.0000
# Epoch 134/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.0157e-04 - accuracy: 1.0000
# Epoch 135/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 136/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0439 - accuracy: 0.9892
# Epoch 137/200
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0035 - accuracy: 0.9998 0s - loss: 0.0037 - accu
# Epoch 138/200
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 139/200
# 80/80 [==============================] - 1s 16ms/step - loss: 5.9155e-04 - accuracy: 1.0000
# Epoch 140/200
# 80/80 [==============================] - 1s 15ms/step - loss: 4.9836e-04 - accuracy: 1.0000
# Epoch 141/200
# 80/80 [==============================] - 1s 16ms/step - loss: 4.4238e-04 - accuracy: 1.0000
# Epoch 142/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.9852e-04 - accuracy: 1.0000
# Epoch 143/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.6592e-04 - accuracy: 1.0000
# Epoch 144/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.3869e-04 - accuracy: 1.0000
# Epoch 145/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.1554e-04 - accuracy: 1.0000 0s - loss: 3.2077e-04 - accuracy
# Epoch 146/200
# 80/80 [==============================] - 1s 16ms/step - loss: 2.9434e-04 - accuracy: 1.0000
# Epoch 147/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.7640e-04 - accuracy: 1.0000
# Epoch 148/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.6069e-04 - accuracy: 1.0000
# Epoch 149/200
# 80/80 [==============================] - 1s 16ms/step - loss: 2.4630e-04 - accuracy: 1.0000
# Epoch 150/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.3350e-04 - accuracy: 1.0000
# Epoch 151/200
# 80/80 [==============================] - 1s 16ms/step - loss: 2.2149e-04 - accuracy: 1.0000
# Epoch 152/200
# 80/80 [==============================] - 1s 16ms/step - loss: 2.1047e-04 - accuracy: 1.0000
# Epoch 153/200
# 80/80 [==============================] - 1s 15ms/step - loss: 2.0020e-04 - accuracy: 1.0000
# Epoch 154/200
# 80/80 [==============================] - 1s 16ms/step - loss: 1.9081e-04 - accuracy: 1.0000
# Epoch 155/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.8186e-04 - accuracy: 1.0000
# Epoch 156/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.7375e-04 - accuracy: 1.0000
# Epoch 157/200
# 80/80 [==============================] - 1s 16ms/step - loss: 1.6605e-04 - accuracy: 1.0000
# Epoch 158/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.5891e-04 - accuracy: 1.0000
# Epoch 159/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.5202e-04 - accuracy: 1.0000
# Epoch 160/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.4570e-04 - accuracy: 1.0000
# Epoch 161/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.3966e-04 - accuracy: 1.0000
# Epoch 162/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.3398e-04 - accuracy: 1.0000 0s - loss: 1
# Epoch 163/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.2832e-04 - accuracy: 1.0000
# Epoch 164/200
# 80/80 [==============================] - 1s 16ms/step - loss: 1.2328e-04 - accuracy: 1.0000
# Epoch 165/200
# 80/80 [==============================] - 1s 16ms/step - loss: 1.1839e-04 - accuracy: 1.0000
# Epoch 166/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.1366e-04 - accuracy: 1.0000
# Epoch 167/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.0920e-04 - accuracy: 1.0000
# Epoch 168/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.0489e-04 - accuracy: 1.0000
# Epoch 169/200
# 80/80 [==============================] - 1s 15ms/step - loss: 1.0082e-04 - accuracy: 1.0000
# Epoch 170/200
# 80/80 [==============================] - 1s 15ms/step - loss: 9.6921e-05 - accuracy: 1.0000
# Epoch 171/200
# 80/80 [==============================] - 1s 16ms/step - loss: 9.3249e-05 - accuracy: 1.0000
# Epoch 172/200
# 80/80 [==============================] - 1s 16ms/step - loss: 8.9692e-05 - accuracy: 1.0000
# Epoch 173/200
# 80/80 [==============================] - 1s 15ms/step - loss: 8.6285e-05 - accuracy: 1.0000
# Epoch 174/200
# 80/80 [==============================] - 1s 15ms/step - loss: 8.2957e-05 - accuracy: 1.0000
# Epoch 175/200
# 80/80 [==============================] - 1s 15ms/step - loss: 7.9823e-05 - accuracy: 1.0000
# Epoch 176/200
# 80/80 [==============================] - 1s 16ms/step - loss: 7.6874e-05 - accuracy: 1.0000
# Epoch 177/200
# 80/80 [==============================] - 1s 16ms/step - loss: 7.3887e-05 - accuracy: 1.0000
# Epoch 178/200
# 80/80 [==============================] - 1s 15ms/step - loss: 7.1112e-05 - accuracy: 1.0000
# Epoch 179/200
# 80/80 [==============================] - 1s 15ms/step - loss: 6.8464e-05 - accuracy: 1.0000 0s - los
# Epoch 180/200
# 80/80 [==============================] - 1s 15ms/step - loss: 6.5961e-05 - accuracy: 1.0000
# Epoch 181/200
# 80/80 [==============================] - 1s 16ms/step - loss: 6.3444e-05 - accuracy: 1.0000
# Epoch 182/200
# 80/80 [==============================] - 1s 15ms/step - loss: 6.1107e-05 - accuracy: 1.0000
# Epoch 183/200
# 80/80 [==============================] - 1s 15ms/step - loss: 5.8773e-05 - accuracy: 1.0000
# Epoch 184/200
# 80/80 [==============================] - 1s 15ms/step - loss: 5.6592e-05 - accuracy: 1.0000
# Epoch 185/200
# 80/80 [==============================] - 1s 15ms/step - loss: 5.4457e-05 - accuracy: 1.0000
# Epoch 186/200
# 80/80 [==============================] - 1s 15ms/step - loss: 5.2434e-05 - accuracy: 1.0000
# Epoch 187/200
# 80/80 [==============================] - 1s 15ms/step - loss: 5.0481e-05 - accuracy: 1.0000
# Epoch 188/200
# 80/80 [==============================] - 1s 15ms/step - loss: 4.8588e-05 - accuracy: 1.0000
# Epoch 189/200
# 80/80 [==============================] - 1s 16ms/step - loss: 4.6771e-05 - accuracy: 1.0000
# Epoch 190/200
# 80/80 [==============================] - 1s 16ms/step - loss: 4.5056e-05 - accuracy: 1.0000
# Epoch 191/200
# 80/80 [==============================] - 1s 15ms/step - loss: 4.3357e-05 - accuracy: 1.0000
# Epoch 192/200
# 80/80 [==============================] - 1s 16ms/step - loss: 4.1765e-05 - accuracy: 1.0000
# Epoch 193/200
# 80/80 [==============================] - 1s 15ms/step - loss: 4.0219e-05 - accuracy: 1.0000
# Epoch 194/200
# 80/80 [==============================] - 1s 16ms/step - loss: 3.8690e-05 - accuracy: 1.0000
# Epoch 195/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.7228e-05 - accuracy: 1.0000
# Epoch 196/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.5842e-05 - accuracy: 1.0000
# Epoch 197/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.4483e-05 - accuracy: 1.0000
# Epoch 198/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.3203e-05 - accuracy: 1.0000
# Epoch 199/200
# 80/80 [==============================] - 1s 15ms/step - loss: 3.1961e-05 - accuracy: 1.0000
# Epoch 200/200
# 80/80 [==============================] - 1s 16ms/step - loss: 3.0766e-05 - accuracy: 1.0000
