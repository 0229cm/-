# %%
import tensorflow as tf
 
 
 
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import seaborn as sns
import soundfile as sf
from scipy.io import wavfile as wav
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
meta_data = pd.read_csv("metadata/UrbanSound8K.csv")  

np.shape(meta_data)
meta_data.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
audio_d_list = []

for index, row in meta_data.iterrows():
    
    file_name = os.path.join(os.path.abspath('metadata/audio/'),
                             'fold'+ str(row["fold"])+'/',
                             str(row["slice_file_name"]))
    
    data = sf.SoundFile(file_name)
    duration = float(meta_data.iloc[index,3])-float(meta_data.iloc[index,2])
    audio_d_list.append([data.channels,
                         data.samplerate,
                         data.subtype[4:],
                         duration])

audio_property = pd.DataFrame(audio_d_list, 
                          columns=['num_channels','sample_rate','bit_depth','duration'])

# %%
def feature_extractor(file_name,scale=False,padding=False,max_pad=None,n=40):
    try:        
        audio, sample_rate = librosa.load(file_name, 
                                          res_type='kaiser_fast') 
        
        mfccs = librosa.feature.mfcc(y = audio, 
                                     sr = sample_rate, 
                                     n_mfcc = n) 
            
        if padding:
            pad_width = max_pad - mfccs.shape[1]
            mfccs = np.pad(mfccs, 
                           pad_width=((0, 0), (0, pad_width)), 
                           mode='constant')
            
        if scale: 
            mfccs = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
     
    return mfccs

# %%
feat_list = []
for index, row in meta_data.iterrows():
    
    file_name = os.path.join(os.path.abspath('metadata/audio/'),
                             'fold'+str(row["fold"])+'/',
                             str(row["slice_file_name"]))
    class_label = row["class"]
    
    data = feature_extractor(file_name,scale=True)
    feat_list.append([data, class_label])

features_1D = pd.DataFrame(feat_list, columns=['feature','class_label'])

print('Processed ', len(features_1D), ' files')
print('Output Feature shape ',np.shape(features_1D.iloc[0,0]))
# Out:
# C:\Users\min\anaconda3\envs\rtx\lib\site-packages\librosa\core\spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   n_fft, y.shape[-1]
# C:\Users\min\anaconda3\envs\rtx\lib\site-packages\librosa\core\spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1103
#   n_fft, y.shape[-1]
# C:\Users\min\anaconda3\envs\rtx\lib\site-packages\librosa\core\spectrum.py:224: UserWarning: n_fft=2048 is too small for input signal of length=1523
#   n_fft, y.shape[-1]
# Processed  8732  files
# Output Feature shape  (40,)

# %%
features_1D.to_pickle("features_1D.pkl")

# %%
feat_list = []
feat_list_padded = []
for index, row in meta_data.iterrows():
    
    file_name = os.path.join(os.path.abspath('metadata/audio/'),
                             'fold'+ str(row["fold"])+'/',
                             str(row["slice_file_name"]))
    class_label = row["class"]
    class_id = row["classID"]
    
    data = feature_extractor(file_name)
    feat_list.append([data, class_id])
    
    data = feature_extractor(file_name,padding=True,max_pad = 174)
    feat_list_padded.append([data, class_label])
    
features_wo_pad = pd.DataFrame(feat_list, columns=['feature','class_label'])
features_2D = pd.DataFrame(feat_list_padded, columns=['feature','class_label'])

print('Processed ', len(features_2D), ' files')
print('Output Feature Padded shape ',np.shape(features_2D.iloc[0,0]))
# Out:
# Processed  8732  files
# Output Feature Padded shape  (40, 174)

# %%
features_wo_pad.to_pickle("features_wo_pad.pkl")
features_2D.to_pickle("features_2D.pkl")

# %%
features_1D = pd.read_pickle("features_1D.pkl")
features_2D = pd.read_pickle("features_2D.pkl")
features_wo_pad = pd.read_pickle("features_wo_pad.pkl")

# %%
sound_class_dic = meta_data.groupby(['class', 'classID']).size()
sound_sample = []

for c in range(10):
    for index, row in features_wo_pad.iterrows():
        if c == row['class_label']:
            sound_sample.append(row)
            break

# %%
X_1D = np.array(features_1D.feature.tolist())
y_1D = np.array(features_1D.class_label.tolist())

label_encoder = LabelEncoder()
yy_1D = to_categorical(label_encoder.fit_transform(y_1D))

# %%
X_2D = np.array(features_2D.feature.tolist())
y_2D = np.array(features_2D.class_label.tolist())

yy_2D = to_categorical(label_encoder.transform(y_2D))

# %%
x_train_sl_1D, x_test_sl_1D, y_train_sl_1D, y_test_sl_1D = train_test_split(X_1D,y_1D,test_size=0.2,random_state =27)
x_train_1D, x_test_1D, y_train_1D, y_test_1D = train_test_split(X_1D, yy_1D, test_size=0.2, random_state = 27)
x_train_2D, x_test_2D, y_train_2D, y_test_2D = train_test_split(X_2D, yy_2D, test_size=0.2, random_state = 27)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split


import tensorflow as tf
import time

# %%
n_labels = yy_1D.shape[1]
in_shape = x_train_1D.shape[1]
n_layers = 2
n_nodes = 100

model_num = 4

model = Sequential()

model.add(Dense(n_nodes, input_shape=(in_shape,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(n_nodes))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(n_labels))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.summary()

score = model.evaluate(x_train_1D, y_train_1D, verbose=0)
accuracy = 100*score[1] 

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               4100
# _________________________________________________________________
# activation_1 (Activation)    (None, 100)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_2 (Activation)    (None, 100)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 15,210
# Trainable params: 15,210
# Non-trainable params: 0
# _________________________________________________________________
# Pre-training accuracy: 10.7802%

# %%
start = time.time()

n_epochs = 200
n_batch = 32

history = model.fit(x_train_1D, 
                    y_train_1D,
                    batch_size=n_batch,
                    epochs=n_epochs,
                    validation_data=(x_test_1D, y_test_1D),
                    verbose=1)

print("time : ", time.time() - start)
# Out:
# Train on 6985 samples, validate on 1747 samples
# Epoch 1/200
# 6985/6985 [==============================] - 1s 77us/step - loss: 0.7972 - accuracy: 0.7228 - val_loss: 0.6795 - val_accuracy: 0.7819
# Epoch 2/200
# 6985/6985 [==============================] - 1s 84us/step - loss: 0.7950 - accuracy: 0.7323 - val_loss: 0.6613 - val_accuracy: 0.7956
# Epoch 3/200
# 6985/6985 [==============================] - 1s 84us/step - loss: 0.8233 - accuracy: 0.7162 - val_loss: 0.6739 - val_accuracy: 0.7831
# Epoch 4/200
# 6985/6985 [==============================] - 1s 79us/step - loss: 0.7703 - accuracy: 0.7317 - val_loss: 0.6712 - val_accuracy: 0.7836
# Epoch 5/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.8059 - accuracy: 0.7267 - val_loss: 0.6710 - val_accuracy: 0.7905
# Epoch 6/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7894 - accuracy: 0.7281 - val_loss: 0.6691 - val_accuracy: 0.7859
# Epoch 7/200
# 6985/6985 [==============================] - 1s 79us/step - loss: 0.7888 - accuracy: 0.7276 - val_loss: 0.6664 - val_accuracy: 0.7911
# Epoch 8/200
# 6985/6985 [==============================] - 1s 73us/step - loss: 0.8146 - accuracy: 0.7224 - val_loss: 0.6711 - val_accuracy: 0.7945
# Epoch 9/200
# 6985/6985 [==============================] - 1s 84us/step - loss: 0.7927 - accuracy: 0.7210 - val_loss: 0.6655 - val_accuracy: 0.7934
# Epoch 10/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7827 - accuracy: 0.7309 - val_loss: 0.6532 - val_accuracy: 0.7956
# Epoch 11/200
# 6985/6985 [==============================] - 1s 72us/step - loss: 0.7923 - accuracy: 0.7276 - val_loss: 0.6681 - val_accuracy: 0.7911
# Epoch 12/200
# 6985/6985 [==============================] - 1s 79us/step - loss: 0.7998 - accuracy: 0.7258 - val_loss: 0.6615 - val_accuracy: 0.7911
# Epoch 13/200
# 6985/6985 [==============================] - 1s 83us/step - loss: 0.7910 - accuracy: 0.7326 - val_loss: 0.6710 - val_accuracy: 0.7934
# Epoch 14/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7847 - accuracy: 0.7296 - val_loss: 0.6656 - val_accuracy: 0.7871
# Epoch 15/200
# 6985/6985 [==============================] - 0s 70us/step - loss: 0.7984 - accuracy: 0.7218 - val_loss: 0.6747 - val_accuracy: 0.7859
# Epoch 16/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7885 - accuracy: 0.7284 - val_loss: 0.6733 - val_accuracy: 0.7922
# Epoch 17/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7900 - accuracy: 0.7291 - val_loss: 0.6685 - val_accuracy: 0.7796
# Epoch 18/200
# 6985/6985 [==============================] - 1s 76us/step - loss: 0.7749 - accuracy: 0.7341 - val_loss: 0.6720 - val_accuracy: 0.7899
# Epoch 19/200
# 6985/6985 [==============================] - 1s 77us/step - loss: 0.7919 - accuracy: 0.7320 - val_loss: 0.6717 - val_accuracy: 0.7859
# Epoch 20/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7875 - accuracy: 0.7300 - val_loss: 0.6649 - val_accuracy: 0.7894
# Epoch 21/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7945 - accuracy: 0.7251 - val_loss: 0.6553 - val_accuracy: 0.7939
# Epoch 22/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7710 - accuracy: 0.7296 - val_loss: 0.6601 - val_accuracy: 0.7894
# Epoch 23/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7939 - accuracy: 0.7246 - val_loss: 0.6705 - val_accuracy: 0.7882
# Epoch 24/200
# 6985/6985 [==============================] - 1s 83us/step - loss: 0.7776 - accuracy: 0.7263 - val_loss: 0.6690 - val_accuracy: 0.7831
# Epoch 25/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7819 - accuracy: 0.7284 - val_loss: 0.6562 - val_accuracy: 0.7848
# Epoch 26/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7920 - accuracy: 0.7314 - val_loss: 0.6714 - val_accuracy: 0.7831
# Epoch 27/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7927 - accuracy: 0.7260 - val_loss: 0.6703 - val_accuracy: 0.7871
# Epoch 28/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7799 - accuracy: 0.7290 - val_loss: 0.6728 - val_accuracy: 0.7922
# Epoch 29/200
# 6985/6985 [==============================] - 1s 74us/step - loss: 0.7909 - accuracy: 0.7288 - val_loss: 0.6571 - val_accuracy: 0.7916
# Epoch 30/200
# 6985/6985 [==============================] - 1s 78us/step - loss: 0.8161 - accuracy: 0.7198 - val_loss: 0.6689 - val_accuracy: 0.7865
# Epoch 31/200
# 6985/6985 [==============================] - 1s 83us/step - loss: 0.7922 - accuracy: 0.7273 - val_loss: 0.6616 - val_accuracy: 0.7899
# Epoch 32/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7818 - accuracy: 0.7336 - val_loss: 0.6653 - val_accuracy: 0.7853
# Epoch 33/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7876 - accuracy: 0.7247 - val_loss: 0.6635 - val_accuracy: 0.7922
# Epoch 34/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7789 - accuracy: 0.7304 - val_loss: 0.6685 - val_accuracy: 0.7876
# Epoch 35/200
# 6985/6985 [==============================] - 1s 83us/step - loss: 0.7764 - accuracy: 0.7321 - val_loss: 0.6741 - val_accuracy: 0.7842
# Epoch 36/200
# 6985/6985 [==============================] - 1s 78us/step - loss: 0.7898 - accuracy: 0.7257 - val_loss: 0.6674 - val_accuracy: 0.7836
# Epoch 37/200
# 6985/6985 [==============================] - 1s 75us/step - loss: 0.7682 - accuracy: 0.7334 - val_loss: 0.6626 - val_accuracy: 0.7876
# Epoch 38/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7799 - accuracy: 0.7277 - val_loss: 0.6683 - val_accuracy: 0.7853
# Epoch 39/200
# 6985/6985 [==============================] - 1s 83us/step - loss: 0.7952 - accuracy: 0.7274 - val_loss: 0.6688 - val_accuracy: 0.7876
# Epoch 40/200
# 6985/6985 [==============================] - 1s 72us/step - loss: 0.7826 - accuracy: 0.7257 - val_loss: 0.6571 - val_accuracy: 0.7882
# Epoch 41/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7691 - accuracy: 0.7329 - val_loss: 0.6660 - val_accuracy: 0.7882
# Epoch 42/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7679 - accuracy: 0.7377 - val_loss: 0.6687 - val_accuracy: 0.7859
# Epoch 43/200
# 6985/6985 [==============================] - 1s 83us/step - loss: 0.7564 - accuracy: 0.7317 - val_loss: 0.6596 - val_accuracy: 0.7894
# Epoch 44/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7771 - accuracy: 0.7276 - val_loss: 0.6648 - val_accuracy: 0.7894
# Epoch 45/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7742 - accuracy: 0.7290 - val_loss: 0.6632 - val_accuracy: 0.7882
# Epoch 46/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7647 - accuracy: 0.7360 - val_loss: 0.6596 - val_accuracy: 0.7945
# Epoch 47/200
# 6985/6985 [==============================] - 1s 75us/step - loss: 0.7632 - accuracy: 0.7339 - val_loss: 0.6508 - val_accuracy: 0.7922
# Epoch 48/200
# 6985/6985 [==============================] - 1s 78us/step - loss: 0.7793 - accuracy: 0.7254 - val_loss: 0.6639 - val_accuracy: 0.7882
# Epoch 49/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7890 - accuracy: 0.7301 - val_loss: 0.6600 - val_accuracy: 0.7939
# Epoch 50/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7898 - accuracy: 0.7227 - val_loss: 0.6593 - val_accuracy: 0.7951
# Epoch 51/200
# 6985/6985 [==============================] - 0s 70us/step - loss: 0.7915 - accuracy: 0.7173 - val_loss: 0.6663 - val_accuracy: 0.7922
# Epoch 52/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7549 - accuracy: 0.7366 - val_loss: 0.6634 - val_accuracy: 0.7871
# Epoch 53/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7578 - accuracy: 0.7330 - val_loss: 0.6633 - val_accuracy: 0.7899
# Epoch 54/200
# 6985/6985 [==============================] - 1s 79us/step - loss: 0.7617 - accuracy: 0.7357 - val_loss: 0.6605 - val_accuracy: 0.7859
# Epoch 55/200
# 6985/6985 [==============================] - 1s 73us/step - loss: 0.7597 - accuracy: 0.7329 - val_loss: 0.6454 - val_accuracy: 0.7951
# Epoch 56/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7803 - accuracy: 0.7321 - val_loss: 0.6561 - val_accuracy: 0.7962
# Epoch 57/200
# 6985/6985 [==============================] - 1s 88us/step - loss: 0.7665 - accuracy: 0.7376 - val_loss: 0.6611 - val_accuracy: 0.7911
# Epoch 58/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7791 - accuracy: 0.7354 - val_loss: 0.6691 - val_accuracy: 0.7899
# Epoch 59/200
# 6985/6985 [==============================] - 1s 79us/step - loss: 0.7614 - accuracy: 0.7386 - val_loss: 0.6656 - val_accuracy: 0.7876
# Epoch 60/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7552 - accuracy: 0.7427 - val_loss: 0.6551 - val_accuracy: 0.7899
# Epoch 61/200
# 6985/6985 [==============================] - 1s 83us/step - loss: 0.7788 - accuracy: 0.7306 - val_loss: 0.6538 - val_accuracy: 0.7951
# Epoch 62/200
# 6985/6985 [==============================] - 0s 69us/step - loss: 0.7447 - accuracy: 0.7364 - val_loss: 0.6600 - val_accuracy: 0.7905
# Epoch 63/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7820 - accuracy: 0.7301 - val_loss: 0.6509 - val_accuracy: 0.7968
# Epoch 64/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7709 - accuracy: 0.7333 - val_loss: 0.6564 - val_accuracy: 0.7894
# Epoch 65/200
# 6985/6985 [==============================] - 1s 77us/step - loss: 0.7634 - accuracy: 0.7339 - val_loss: 0.6569 - val_accuracy: 0.7922
# Epoch 66/200
# 6985/6985 [==============================] - 1s 74us/step - loss: 0.7760 - accuracy: 0.7253 - val_loss: 0.6568 - val_accuracy: 0.7945
# Epoch 67/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7558 - accuracy: 0.7361 - val_loss: 0.6535 - val_accuracy: 0.7859
# Epoch 68/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7611 - accuracy: 0.7327 - val_loss: 0.6575 - val_accuracy: 0.7934
# Epoch 69/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7675 - accuracy: 0.7374 - val_loss: 0.6581 - val_accuracy: 0.7882
# Epoch 70/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7631 - accuracy: 0.7359 - val_loss: 0.6520 - val_accuracy: 0.7928
# Epoch 71/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7815 - accuracy: 0.7347 - val_loss: 0.6518 - val_accuracy: 0.7882
# Epoch 72/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7544 - accuracy: 0.7423 - val_loss: 0.6466 - val_accuracy: 0.7922
# Epoch 73/200
# 6985/6985 [==============================] - 0s 70us/step - loss: 0.7763 - accuracy: 0.7369 - val_loss: 0.6513 - val_accuracy: 0.7916
# Epoch 74/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7633 - accuracy: 0.7349 - val_loss: 0.6529 - val_accuracy: 0.7928
# Epoch 75/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7554 - accuracy: 0.7380 - val_loss: 0.6446 - val_accuracy: 0.7979
# Epoch 76/200
# 6985/6985 [==============================] - 1s 75us/step - loss: 0.7566 - accuracy: 0.7379 - val_loss: 0.6396 - val_accuracy: 0.7962
# Epoch 77/200
# 6985/6985 [==============================] - 1s 76us/step - loss: 0.7604 - accuracy: 0.7334 - val_loss: 0.6474 - val_accuracy: 0.7962
# Epoch 78/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7575 - accuracy: 0.7354 - val_loss: 0.6467 - val_accuracy: 0.8019
# Epoch 79/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7558 - accuracy: 0.7394 - val_loss: 0.6569 - val_accuracy: 0.7934
# Epoch 80/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7514 - accuracy: 0.7389 - val_loss: 0.6643 - val_accuracy: 0.7922
# Epoch 81/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7580 - accuracy: 0.7357 - val_loss: 0.6541 - val_accuracy: 0.7865
# Epoch 82/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7675 - accuracy: 0.7359 - val_loss: 0.6525 - val_accuracy: 0.7882
# Epoch 83/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7704 - accuracy: 0.7379 - val_loss: 0.6578 - val_accuracy: 0.7934
# Epoch 84/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7476 - accuracy: 0.7420 - val_loss: 0.6444 - val_accuracy: 0.8037
# Epoch 85/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7468 - accuracy: 0.7397 - val_loss: 0.6525 - val_accuracy: 0.7951
# Epoch 86/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7699 - accuracy: 0.7290 - val_loss: 0.6562 - val_accuracy: 0.7974
# Epoch 87/200
# 6985/6985 [==============================] - 1s 74us/step - loss: 0.7589 - accuracy: 0.7353 - val_loss: 0.6483 - val_accuracy: 0.7991
# Epoch 88/200
# 6985/6985 [==============================] - 1s 77us/step - loss: 0.7611 - accuracy: 0.7424 - val_loss: 0.6580 - val_accuracy: 0.7956
# Epoch 89/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7514 - accuracy: 0.7427 - val_loss: 0.6549 - val_accuracy: 0.7939
# Epoch 90/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7640 - accuracy: 0.7410 - val_loss: 0.6548 - val_accuracy: 0.7945
# Epoch 91/200
# 6985/6985 [==============================] - 0s 70us/step - loss: 0.7530 - accuracy: 0.7349 - val_loss: 0.6450 - val_accuracy: 0.8031
# Epoch 92/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7520 - accuracy: 0.7473 - val_loss: 0.6524 - val_accuracy: 0.7894
# Epoch 93/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7406 - accuracy: 0.7420 - val_loss: 0.6501 - val_accuracy: 0.7934
# Epoch 94/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7775 - accuracy: 0.7406 - val_loss: 0.6527 - val_accuracy: 0.7979
# Epoch 95/200
# 6985/6985 [==============================] - 1s 74us/step - loss: 0.7539 - accuracy: 0.7423 - val_loss: 0.6450 - val_accuracy: 0.8037
# Epoch 96/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7515 - accuracy: 0.7361 - val_loss: 0.6531 - val_accuracy: 0.7956
# Epoch 97/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7406 - accuracy: 0.7432 - val_loss: 0.6629 - val_accuracy: 0.7934
# Epoch 98/200
# 6985/6985 [==============================] - 1s 73us/step - loss: 0.7502 - accuracy: 0.7424 - val_loss: 0.6536 - val_accuracy: 0.8002
# Epoch 99/200
# 6985/6985 [==============================] - 1s 79us/step - loss: 0.7611 - accuracy: 0.7390 - val_loss: 0.6507 - val_accuracy: 0.7951
# Epoch 100/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7754 - accuracy: 0.7384 - val_loss: 0.6543 - val_accuracy: 0.7962
# Epoch 101/200
# 6985/6985 [==============================] - 1s 85us/step - loss: 0.7426 - accuracy: 0.7403 - val_loss: 0.6548 - val_accuracy: 0.7962
# Epoch 102/200
# 6985/6985 [==============================] - 0s 70us/step - loss: 0.7524 - accuracy: 0.7320 - val_loss: 0.6501 - val_accuracy: 0.8002
# Epoch 103/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7487 - accuracy: 0.7443 - val_loss: 0.6513 - val_accuracy: 0.7974
# Epoch 104/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7528 - accuracy: 0.7383 - val_loss: 0.6453 - val_accuracy: 0.8014
# Epoch 105/200
# 6985/6985 [==============================] - 1s 76us/step - loss: 0.7387 - accuracy: 0.7432 - val_loss: 0.6465 - val_accuracy: 0.7951
# Epoch 106/200
# 6985/6985 [==============================] - 1s 76us/step - loss: 0.7691 - accuracy: 0.7386 - val_loss: 0.6590 - val_accuracy: 0.7979
# Epoch 107/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7532 - accuracy: 0.7396 - val_loss: 0.6467 - val_accuracy: 0.7934
# Epoch 108/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7324 - accuracy: 0.7528 - val_loss: 0.6444 - val_accuracy: 0.7951
# Epoch 109/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7545 - accuracy: 0.7369 - val_loss: 0.6478 - val_accuracy: 0.8025
# Epoch 110/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7563 - accuracy: 0.7374 - val_loss: 0.6502 - val_accuracy: 0.7991
# Epoch 111/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7409 - accuracy: 0.7460 - val_loss: 0.6523 - val_accuracy: 0.7962
# Epoch 112/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7609 - accuracy: 0.7426 - val_loss: 0.6486 - val_accuracy: 0.7962
# Epoch 113/200
# 6985/6985 [==============================] - 0s 70us/step - loss: 0.7410 - accuracy: 0.7476 - val_loss: 0.6546 - val_accuracy: 0.7928
# Epoch 114/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7524 - accuracy: 0.7373 - val_loss: 0.6531 - val_accuracy: 0.7962
# Epoch 115/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7628 - accuracy: 0.7380 - val_loss: 0.6528 - val_accuracy: 0.7894
# Epoch 116/200
# 6985/6985 [==============================] - 1s 74us/step - loss: 0.7404 - accuracy: 0.7490 - val_loss: 0.6441 - val_accuracy: 0.7956
# Epoch 117/200
# 6985/6985 [==============================] - 1s 75us/step - loss: 0.7406 - accuracy: 0.7409 - val_loss: 0.6384 - val_accuracy: 0.8042
# Epoch 118/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7320 - accuracy: 0.7477 - val_loss: 0.6470 - val_accuracy: 0.7939
# Epoch 119/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7261 - accuracy: 0.7475 - val_loss: 0.6393 - val_accuracy: 0.8042
# Epoch 120/200
# 6985/6985 [==============================] - 0s 70us/step - loss: 0.7290 - accuracy: 0.7442 - val_loss: 0.6524 - val_accuracy: 0.7939
# Epoch 121/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7308 - accuracy: 0.7476 - val_loss: 0.6397 - val_accuracy: 0.8082
# Epoch 122/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7380 - accuracy: 0.7466 - val_loss: 0.6277 - val_accuracy: 0.8065
# Epoch 123/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7374 - accuracy: 0.7427 - val_loss: 0.6420 - val_accuracy: 0.7997
# Epoch 124/200
# 6985/6985 [==============================] - 0s 69us/step - loss: 0.7226 - accuracy: 0.7462 - val_loss: 0.6347 - val_accuracy: 0.8019
# Epoch 125/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7340 - accuracy: 0.7445 - val_loss: 0.6347 - val_accuracy: 0.7979
# Epoch 126/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7278 - accuracy: 0.7529 - val_loss: 0.6378 - val_accuracy: 0.7951
# Epoch 127/200
# 6985/6985 [==============================] - 1s 75us/step - loss: 0.7500 - accuracy: 0.7370 - val_loss: 0.6283 - val_accuracy: 0.8025
# Epoch 128/200
# 6985/6985 [==============================] - 1s 73us/step - loss: 0.7532 - accuracy: 0.7417 - val_loss: 0.6478 - val_accuracy: 0.7968
# Epoch 129/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7511 - accuracy: 0.7374 - val_loss: 0.6470 - val_accuracy: 0.7979
# Epoch 130/200
# 6985/6985 [==============================] - 1s 85us/step - loss: 0.7460 - accuracy: 0.7457 - val_loss: 0.6267 - val_accuracy: 0.8019
# Epoch 131/200
# 6985/6985 [==============================] - 0s 70us/step - loss: 0.7370 - accuracy: 0.7432 - val_loss: 0.6374 - val_accuracy: 0.7997
# Epoch 132/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7389 - accuracy: 0.7413 - val_loss: 0.6363 - val_accuracy: 0.7962
# Epoch 133/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7427 - accuracy: 0.7416 - val_loss: 0.6392 - val_accuracy: 0.8002
# Epoch 134/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7396 - accuracy: 0.7479 - val_loss: 0.6473 - val_accuracy: 0.7985
# Epoch 135/200
# 6985/6985 [==============================] - 0s 69us/step - loss: 0.7344 - accuracy: 0.7430 - val_loss: 0.6537 - val_accuracy: 0.7968
# Epoch 136/200
# 6985/6985 [==============================] - 1s 83us/step - loss: 0.7391 - accuracy: 0.7476 - val_loss: 0.6437 - val_accuracy: 0.8002
# Epoch 137/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7324 - accuracy: 0.7515 - val_loss: 0.6492 - val_accuracy: 0.7951
# Epoch 138/200
# 6985/6985 [==============================] - 1s 75us/step - loss: 0.7071 - accuracy: 0.7548 - val_loss: 0.6378 - val_accuracy: 0.7979
# Epoch 139/200
# 6985/6985 [==============================] - 1s 75us/step - loss: 0.7385 - accuracy: 0.7487 - val_loss: 0.6336 - val_accuracy: 0.7962
# Epoch 140/200
# 6985/6985 [==============================] - 1s 84us/step - loss: 0.7237 - accuracy: 0.7472 - val_loss: 0.6473 - val_accuracy: 0.7939
# Epoch 141/200
# 6985/6985 [==============================] - 1s 83us/step - loss: 0.7319 - accuracy: 0.7442 - val_loss: 0.6297 - val_accuracy: 0.8094
# Epoch 142/200
# 6985/6985 [==============================] - 0s 69us/step - loss: 0.7387 - accuracy: 0.7430 - val_loss: 0.6357 - val_accuracy: 0.8008
# Epoch 143/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7302 - accuracy: 0.7476 - val_loss: 0.6306 - val_accuracy: 0.8105
# Epoch 144/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7317 - accuracy: 0.7445 - val_loss: 0.6418 - val_accuracy: 0.7962
# Epoch 145/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7360 - accuracy: 0.7483 - val_loss: 0.6386 - val_accuracy: 0.7928
# Epoch 146/200
# 6985/6985 [==============================] - 1s 72us/step - loss: 0.7412 - accuracy: 0.7427 - val_loss: 0.6461 - val_accuracy: 0.7979
# Epoch 147/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7370 - accuracy: 0.7382 - val_loss: 0.6370 - val_accuracy: 0.8025
# Epoch 148/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7293 - accuracy: 0.7522 - val_loss: 0.6375 - val_accuracy: 0.7905
# Epoch 149/200
# 6985/6985 [==============================] - 1s 73us/step - loss: 0.7228 - accuracy: 0.7469 - val_loss: 0.6405 - val_accuracy: 0.7968
# Epoch 150/200
# 6985/6985 [==============================] - 1s 77us/step - loss: 0.7267 - accuracy: 0.7450 - val_loss: 0.6385 - val_accuracy: 0.7968
# Epoch 151/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7173 - accuracy: 0.7499 - val_loss: 0.6363 - val_accuracy: 0.7985
# Epoch 152/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7249 - accuracy: 0.7522 - val_loss: 0.6292 - val_accuracy: 0.8031
# Epoch 153/200
# 6985/6985 [==============================] - 0s 69us/step - loss: 0.7497 - accuracy: 0.7462 - val_loss: 0.6494 - val_accuracy: 0.7962
# Epoch 154/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7221 - accuracy: 0.7532 - val_loss: 0.6407 - val_accuracy: 0.7974
# Epoch 155/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7365 - accuracy: 0.7499 - val_loss: 0.6312 - val_accuracy: 0.8071
# Epoch 156/200
# 6985/6985 [==============================] - 1s 79us/step - loss: 0.7097 - accuracy: 0.7510 - val_loss: 0.6395 - val_accuracy: 0.7985
# Epoch 157/200
# 6985/6985 [==============================] - 1s 72us/step - loss: 0.7326 - accuracy: 0.7447 - val_loss: 0.6387 - val_accuracy: 0.7956
# Epoch 158/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7259 - accuracy: 0.7490 - val_loss: 0.6300 - val_accuracy: 0.8014
# Epoch 159/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7461 - accuracy: 0.7437 - val_loss: 0.6316 - val_accuracy: 0.8019
# Epoch 160/200
# 6985/6985 [==============================] - 1s 73us/step - loss: 0.7367 - accuracy: 0.7429 - val_loss: 0.6331 - val_accuracy: 0.8019
# Epoch 161/200
# 6985/6985 [==============================] - 1s 77us/step - loss: 0.7469 - accuracy: 0.7465 - val_loss: 0.6439 - val_accuracy: 0.8037
# Epoch 162/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7318 - accuracy: 0.7522 - val_loss: 0.6367 - val_accuracy: 0.8014
# Epoch 163/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7272 - accuracy: 0.7487 - val_loss: 0.6312 - val_accuracy: 0.8002
# Epoch 164/200
# 6985/6985 [==============================] - 0s 69us/step - loss: 0.7259 - accuracy: 0.7469 - val_loss: 0.6332 - val_accuracy: 0.8042
# Epoch 165/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7197 - accuracy: 0.7563 - val_loss: 0.6392 - val_accuracy: 0.8014
# Epoch 166/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7171 - accuracy: 0.7543 - val_loss: 0.6273 - val_accuracy: 0.8008
# Epoch 167/200
# 6985/6985 [==============================] - 1s 78us/step - loss: 0.7356 - accuracy: 0.7483 - val_loss: 0.6325 - val_accuracy: 0.8042
# Epoch 168/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7334 - accuracy: 0.7429 - val_loss: 0.6299 - val_accuracy: 0.8031
# Epoch 169/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7197 - accuracy: 0.7497 - val_loss: 0.6340 - val_accuracy: 0.8014
# Epoch 170/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7271 - accuracy: 0.7455 - val_loss: 0.6307 - val_accuracy: 0.8014
# Epoch 171/200
# 6985/6985 [==============================] - 1s 73us/step - loss: 0.7394 - accuracy: 0.7465 - val_loss: 0.6369 - val_accuracy: 0.8122
# Epoch 172/200
# 6985/6985 [==============================] - 1s 77us/step - loss: 0.7106 - accuracy: 0.7525 - val_loss: 0.6326 - val_accuracy: 0.8031
# Epoch 173/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7239 - accuracy: 0.7513 - val_loss: 0.6284 - val_accuracy: 0.8037
# Epoch 174/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7210 - accuracy: 0.7487 - val_loss: 0.6425 - val_accuracy: 0.7997
# Epoch 175/200
# 6985/6985 [==============================] - 0s 68us/step - loss: 0.7337 - accuracy: 0.7446 - val_loss: 0.6336 - val_accuracy: 0.8008
# Epoch 176/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7276 - accuracy: 0.7516 - val_loss: 0.6317 - val_accuracy: 0.8037
# Epoch 177/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7296 - accuracy: 0.7437 - val_loss: 0.6381 - val_accuracy: 0.8019
# Epoch 178/200
# 6985/6985 [==============================] - 1s 79us/step - loss: 0.7270 - accuracy: 0.7513 - val_loss: 0.6299 - val_accuracy: 0.8037
# Epoch 179/200
# 6985/6985 [==============================] - 0s 71us/step - loss: 0.7233 - accuracy: 0.7466 - val_loss: 0.6316 - val_accuracy: 0.8094
# Epoch 180/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7177 - accuracy: 0.7473 - val_loss: 0.6281 - val_accuracy: 0.8077
# Epoch 181/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.6967 - accuracy: 0.7606 - val_loss: 0.6235 - val_accuracy: 0.8054
# Epoch 182/200
# 6985/6985 [==============================] - 1s 74us/step - loss: 0.7279 - accuracy: 0.7447 - val_loss: 0.6331 - val_accuracy: 0.8048
# Epoch 183/200
# 6985/6985 [==============================] - 1s 76us/step - loss: 0.7065 - accuracy: 0.7497 - val_loss: 0.6285 - val_accuracy: 0.8019
# Epoch 184/200
# 6985/6985 [==============================] - 1s 78us/step - loss: 0.7258 - accuracy: 0.7472 - val_loss: 0.6332 - val_accuracy: 0.8002
# Epoch 185/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7163 - accuracy: 0.7506 - val_loss: 0.6363 - val_accuracy: 0.8048
# Epoch 186/200
# 6985/6985 [==============================] - 0s 69us/step - loss: 0.7186 - accuracy: 0.7512 - val_loss: 0.6433 - val_accuracy: 0.8048
# Epoch 187/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7128 - accuracy: 0.7476 - val_loss: 0.6241 - val_accuracy: 0.8060
# Epoch 188/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7191 - accuracy: 0.7479 - val_loss: 0.6267 - val_accuracy: 0.8054
# Epoch 189/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7240 - accuracy: 0.7433 - val_loss: 0.6349 - val_accuracy: 0.8014
# Epoch 190/200
# 6985/6985 [==============================] - 0s 70us/step - loss: 0.7267 - accuracy: 0.7483 - val_loss: 0.6288 - val_accuracy: 0.8037
# Epoch 191/200
# 6985/6985 [==============================] - 1s 82us/step - loss: 0.7200 - accuracy: 0.7483 - val_loss: 0.6419 - val_accuracy: 0.7985
# Epoch 192/200
# 6985/6985 [==============================] - 1s 81us/step - loss: 0.7478 - accuracy: 0.7430 - val_loss: 0.6334 - val_accuracy: 0.8002
# Epoch 193/200
# 6985/6985 [==============================] - 1s 74us/step - loss: 0.7108 - accuracy: 0.7538 - val_loss: 0.6265 - val_accuracy: 0.8042
# Epoch 194/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7288 - accuracy: 0.7467 - val_loss: 0.6303 - val_accuracy: 0.8002
# Epoch 195/200
# 6985/6985 [==============================] - 1s 89us/step - loss: 0.7221 - accuracy: 0.7485 - val_loss: 0.6314 - val_accuracy: 0.8048
# Epoch 196/200
# 6985/6985 [==============================] - 1s 89us/step - loss: 0.7356 - accuracy: 0.7460 - val_loss: 0.6367 - val_accuracy: 0.8048
# Epoch 197/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7175 - accuracy: 0.7579 - val_loss: 0.6237 - val_accuracy: 0.8082
# Epoch 198/200
# 6985/6985 [==============================] - 1s 90us/step - loss: 0.7183 - accuracy: 0.7559 - val_loss: 0.6380 - val_accuracy: 0.8048
# Epoch 199/200
# 6985/6985 [==============================] - 1s 90us/step - loss: 0.7143 - accuracy: 0.7500 - val_loss: 0.6322 - val_accuracy: 0.8008
# Epoch 200/200
# 6985/6985 [==============================] - 1s 80us/step - loss: 0.7164 - accuracy: 0.7496 - val_loss: 0.6389 - val_accuracy: 0.7997
# time :  110.25079298019409
